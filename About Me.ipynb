# %% [markdown]
# # About Me

# %%
print ("Hi There!")
print ("My name is Mela, I was graduated from Statistics Padjadjaran University")
print ("I have been working in Risk Management Area since 2013")
print ("Glad to see you, thank you for visiting my Github!")
# Out:
# Hi There!
# My name is Mela, I was graduated from Statistics Padjadjaran University
# I have been working in Risk Management Area since 2013
# Glad to see you, thank you for visiting my Github!
